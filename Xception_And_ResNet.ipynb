# %%
import tensorflow
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.xception import Xception
from keras.applications.vgg16 import VGG16
from keras.applications.resnet50 import ResNet50
from keras.layers import Input, Flatten, Dense, Dropout
import matplotlib.pyplot as plt

# %%
# !unzip /content/drive/MyDrive/Sih/Medicinalplantdataset.zip

# %%
dataset = '/content/Medicinal plant dataset'

# %%
data_gen = ImageDataGenerator(rescale=1./255, rotation_range=180, brightness_range=[0.2, 1.0], horizontal_flip=True,validation_split=0.2)
train_imgs = data_gen.flow_from_directory(dataset, target_size=(224,224),class_mode='categorical', subset='training', shuffle=True)
test_imgs = data_gen.flow_from_directory(dataset, target_size=(224,224),class_mode='categorical', subset='validation', shuffle=True)
# Out:
# Found 4765 images belonging to 40 classes.
# Found 1180 images belonging to 40 classes.

# %%
input = Input(shape=(299, 299, 3))
model = Xception(include_top=False, weights='imagenet', input_tensor=input)
model.trainable=True
# for layers in model.layers[-1:-5:-1]:
#   layers.trainable=True

# %%
output = model.output
x = Flatten()(output)
x = Dense(1024, activation='relu')(x)
# x = Dense(512, activation='relu')(x)
output = Dense(40, activation='softmax')(x)

# %%
model = keras.Model(inputs=input, outputs=output)

# %%
# lr_schedule = keras.callbacks.LearningRateScheduler(
#     lambda epoch: 1e-8 * 10**(epoch / 20))
# callbacks=[lr_schedule]
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
callbacks = [checkpoint]

optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.09)

model.compile(loss=tensorflow.keras.losses.CategoricalCrossentropy(), optimizer=optimizer, metrics=['accuracy'])

res_history = model.fit(train_imgs, epochs=10,validation_data=test_imgs, callbacks = callbacks)
# Out:
# Epoch 1/10
# 149/149 [==============================] - ETA: 0s - loss: 1.4739 - accuracy: 0.6105
# Epoch 1: val_accuracy improved from -inf to 0.74068, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 149/149 [==============================] - 256s 2s/step - loss: 1.4739 - accuracy: 0.6105 - val_loss: 0.7882 - val_accuracy: 0.7407
# Epoch 2/10
# 149/149 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.9024
# Epoch 2: val_accuracy improved from 0.74068 to 0.91610, saving model to best_model.h5
# 149/149 [==============================] - 208s 1s/step - loss: 0.3175 - accuracy: 0.9024 - val_loss: 0.2756 - val_accuracy: 0.9161
# Epoch 3/10
# 149/149 [==============================] - ETA: 0s - loss: 0.1707 - accuracy: 0.9490
# Epoch 3: val_accuracy improved from 0.91610 to 0.94068, saving model to best_model.h5
# 149/149 [==============================] - 211s 1s/step - loss: 0.1707 - accuracy: 0.9490 - val_loss: 0.2019 - val_accuracy: 0.9407
# Epoch 4/10
# 149/149 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9647
# Epoch 4: val_accuracy did not improve from 0.94068
# 149/149 [==============================] - 201s 1s/step - loss: 0.1093 - accuracy: 0.9647 - val_loss: 0.2327 - val_accuracy: 0.9398
# Epoch 5/10
# 149/149 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9712
# Epoch 5: val_accuracy improved from 0.94068 to 0.95932, saving model to best_model.h5
# 149/149 [==============================] - 210s 1s/step - loss: 0.0849 - accuracy: 0.9712 - val_loss: 0.1428 - val_accuracy: 0.9593
# Epoch 6/10
# 149/149 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9752
# Epoch 6: val_accuracy improved from 0.95932 to 0.96695, saving model to best_model.h5
# 149/149 [==============================] - 210s 1s/step - loss: 0.0688 - accuracy: 0.9752 - val_loss: 0.1182 - val_accuracy: 0.9669
# Epoch 7/10
# 149/149 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9832
# Epoch 7: val_accuracy did not improve from 0.96695
# 149/149 [==============================] - 210s 1s/step - loss: 0.0545 - accuracy: 0.9832 - val_loss: 0.1442 - val_accuracy: 0.9559
# Epoch 8/10
# 149/149 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9861
# Epoch 8: val_accuracy did not improve from 0.96695
# 149/149 [==============================] - 210s 1s/step - loss: 0.0440 - accuracy: 0.9861 - val_loss: 0.1418 - val_accuracy: 0.9627
# Epoch 9/10
# 149/149 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9876
# Epoch 9: val_accuracy did not improve from 0.96695
# 149/149 [==============================] - 197s 1s/step - loss: 0.0350 - accuracy: 0.9876 - val_loss: 0.1441 - val_accuracy: 0.9619
# Epoch 10/10
# 149/149 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9889
# Epoch 10: val_accuracy did not improve from 0.96695
# 149/149 [==============================] - 200s 1s/step - loss: 0.0359 - accuracy: 0.9889 - val_loss: 0.1274 - val_accuracy: 0.9619

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(res_history.history['accuracy'])
plt.plot(res_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(res_history.history['loss'])
plt.plot(res_history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
resent = keras.models.load_model("/content/best_res_model_.h5")

# %%
resent.save("/content/drive/MyDrive/Sih/Resnet_new.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
res_input = Input(shape=(224, 224, 3))
res_model = ResNet50(include_top=False, weights='imagenet', input_tensor=res_input)
res_model.trainable=True
res_output = res_model.output
res_x = Flatten()(res_output)
res_x = Dense(1024, activation='relu')(res_x)
# x = Dense(512, activation='relu')(x)
res_final = Dense(40, activation='softmax')(res_x)
res_model = keras.Model(inputs=res_input, outputs=res_final)
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint('best_res_model_.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
callbacks = [checkpoint]

optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.09)

res_model.compile(loss=tensorflow.keras.losses.CategoricalCrossentropy(), optimizer=optimizer, metrics=['accuracy'])

res_history_ = res_model.fit(train_imgs, epochs=20,validation_data=test_imgs, callbacks = callbacks)
# Out:
# Epoch 1/20
# 149/149 [==============================] - ETA: 0s - loss: 3.1114 - accuracy: 0.4143
# Epoch 1: val_accuracy improved from -inf to 0.02119, saving model to best_res_model_.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 149/149 [==============================] - 141s 792ms/step - loss: 3.1114 - accuracy: 0.4143 - val_loss: 3.9820 - val_accuracy: 0.0212
# Epoch 2/20
# 149/149 [==============================] - ETA: 0s - loss: 0.5307 - accuracy: 0.8407
# Epoch 2: val_accuracy improved from 0.02119 to 0.02203, saving model to best_res_model_.h5
# 149/149 [==============================] - 116s 778ms/step - loss: 0.5307 - accuracy: 0.8407 - val_loss: 4.7245 - val_accuracy: 0.0220
# Epoch 3/20
# 149/149 [==============================] - ETA: 0s - loss: 0.2635 - accuracy: 0.9148
# Epoch 3: val_accuracy improved from 0.02203 to 0.02373, saving model to best_res_model_.h5
# 149/149 [==============================] - 124s 834ms/step - loss: 0.2635 - accuracy: 0.9148 - val_loss: 5.8755 - val_accuracy: 0.0237
# Epoch 4/20
# 149/149 [==============================] - ETA: 0s - loss: 0.1629 - accuracy: 0.9477
# Epoch 4: val_accuracy did not improve from 0.02373
# 149/149 [==============================] - 104s 701ms/step - loss: 0.1629 - accuracy: 0.9477 - val_loss: 6.9676 - val_accuracy: 0.0186
# Epoch 5/20
# 149/149 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9601
# Epoch 5: val_accuracy improved from 0.02373 to 0.03136, saving model to best_res_model_.h5
# 149/149 [==============================] - 119s 798ms/step - loss: 0.1125 - accuracy: 0.9601 - val_loss: 7.4390 - val_accuracy: 0.0314
# Epoch 6/20
# 149/149 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9624
# Epoch 6: val_accuracy improved from 0.03136 to 0.27119, saving model to best_res_model_.h5
# 149/149 [==============================] - 117s 783ms/step - loss: 0.1008 - accuracy: 0.9624 - val_loss: 4.0399 - val_accuracy: 0.2712
# Epoch 7/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0800 - accuracy: 0.9719
# Epoch 7: val_accuracy improved from 0.27119 to 0.59322, saving model to best_res_model_.h5
# 149/149 [==============================] - 112s 749ms/step - loss: 0.0800 - accuracy: 0.9719 - val_loss: 2.1640 - val_accuracy: 0.5932
# Epoch 8/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9778
# Epoch 8: val_accuracy improved from 0.59322 to 0.89831, saving model to best_res_model_.h5
# 149/149 [==============================] - 116s 780ms/step - loss: 0.0652 - accuracy: 0.9778 - val_loss: 0.3543 - val_accuracy: 0.8983
# Epoch 9/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9832
# Epoch 9: val_accuracy improved from 0.89831 to 0.92627, saving model to best_res_model_.h5
# 149/149 [==============================] - 119s 797ms/step - loss: 0.0541 - accuracy: 0.9832 - val_loss: 0.2120 - val_accuracy: 0.9263
# Epoch 10/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9807
# Epoch 10: val_accuracy improved from 0.92627 to 0.95678, saving model to best_res_model_.h5
# 149/149 [==============================] - 112s 748ms/step - loss: 0.0525 - accuracy: 0.9807 - val_loss: 0.1245 - val_accuracy: 0.9568
# Epoch 11/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9866
# Epoch 11: val_accuracy improved from 0.95678 to 0.96780, saving model to best_res_model_.h5
# 149/149 [==============================] - 115s 773ms/step - loss: 0.0367 - accuracy: 0.9866 - val_loss: 0.1083 - val_accuracy: 0.9678
# Epoch 12/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9864
# Epoch 12: val_accuracy did not improve from 0.96780
# 149/149 [==============================] - 105s 703ms/step - loss: 0.0343 - accuracy: 0.9864 - val_loss: 0.1031 - val_accuracy: 0.9636
# Epoch 13/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9891
# Epoch 13: val_accuracy did not improve from 0.96780
# 149/149 [==============================] - 105s 704ms/step - loss: 0.0288 - accuracy: 0.9891 - val_loss: 0.1460 - val_accuracy: 0.9551
# Epoch 14/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9864
# Epoch 14: val_accuracy did not improve from 0.96780
# 149/149 [==============================] - 105s 705ms/step - loss: 0.0338 - accuracy: 0.9864 - val_loss: 0.1120 - val_accuracy: 0.9636
# Epoch 15/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9895
# Epoch 15: val_accuracy improved from 0.96780 to 0.96864, saving model to best_res_model_.h5
# 149/149 [==============================] - 112s 748ms/step - loss: 0.0276 - accuracy: 0.9895 - val_loss: 0.1030 - val_accuracy: 0.9686
# Epoch 16/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9903
# Epoch 16: val_accuracy did not improve from 0.96864
# 149/149 [==============================] - 105s 703ms/step - loss: 0.0245 - accuracy: 0.9903 - val_loss: 0.1661 - val_accuracy: 0.9449
# Epoch 17/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9882
# Epoch 17: val_accuracy did not improve from 0.96864
# 149/149 [==============================] - 105s 703ms/step - loss: 0.0341 - accuracy: 0.9882 - val_loss: 0.1549 - val_accuracy: 0.9610
# Epoch 18/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9910
# Epoch 18: val_accuracy improved from 0.96864 to 0.96949, saving model to best_res_model_.h5
# 149/149 [==============================] - 129s 864ms/step - loss: 0.0274 - accuracy: 0.9910 - val_loss: 0.0961 - val_accuracy: 0.9695
# Epoch 19/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9914
# Epoch 19: val_accuracy did not improve from 0.96949
# 149/149 [==============================] - 106s 712ms/step - loss: 0.0213 - accuracy: 0.9914 - val_loss: 0.1345 - val_accuracy: 0.9534
# Epoch 20/20
# 149/149 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9901
# Epoch 20: val_accuracy improved from 0.96949 to 0.97542, saving model to best_res_model_.h5
# 149/149 [==============================] - 111s 748ms/step - loss: 0.0245 - accuracy: 0.9901 - val_loss: 0.0778 - val_accuracy: 0.9754

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(res_history_.history['accuracy'])
plt.plot(res_history_.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(res_history_.history['loss'])
plt.plot(res_history_.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
results = plants_model.evaluate(test_imgs)

accuracy = results[1]
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# 38/38 [==============================] - 38s 934ms/step - loss: 0.1935 - accuracy: 0.9437
# Accuracy: 94.37%

# %%
data_gen = ImageDataGenerator(rescale=1./255, rotation_range=180, brightness_range=[0.2, 1.0], horizontal_flip=True)
imgs = data_gen.flow_from_directory(dataset, target_size=(299,299),class_mode='categorical', shuffle=True)
# Out:
# Found 6005 images belonging to 40 classes.

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold

# Initialize KFold with k folds
kf = KFold(n_splits=k, shuffle=True, random_state=42)


# Define your model here (e.g., a simple example)
k = 5  # Number of folds
batch_size = 32
epochs = 10
kf = KFold(n_splits=k, shuffle=True, random_state=42)
for i in range(11):
# Extract the data and labels from the data generator
  data, labels = test_imgs.next()

# Initialize StratifiedKFold with k folds
# kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)


# Loop through each fold
  for fold_num, (train_indices, val_indices) in enumerate(kf.split(data, np.argmax(labels, axis=1))):
      print(f"Fold {fold_num + 1}/{k}")

      # Split the data into training and validation sets for this fold
      x_train, y_train = data[train_indices], labels[train_indices]
      x_val, y_val = data[val_indices], labels[val_indices]

      # Train your model on the training data for this fold
      # history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val))

      # Evaluate the model on the validation data for this fold
      loss, accuracy = plants_model.evaluate(x_val, y_val)
      print(f"Validation Accuracy: {accuracy * 100:.2f}%")

# Calculate and print the mean and standard deviation of validation accuracies across folds
# You can also save these accuracies to analyze further.
# Out:
# Fold 1/10
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0718 - accuracy: 1.0000
# Validation Accuracy: 100.00%
# Fold 2/10
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0289 - accuracy: 1.0000
# Validation Accuracy: 100.00%
# Fold 3/10
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5155 - accuracy: 0.6667
# Validation Accuracy: 66.67%
# Fold 4/10
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0979 - accuracy: 1.0000
# Validation Accuracy: 100.00%
# Fold 5/10
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0174 - accuracy: 1.0000
# Validation Accuracy: 100.00%
# Fold 6/10
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2362 - accuracy: 1.0000
# Validation Accuracy: 100.00%
# Fold 7/10
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0046 - accuracy: 1.0000
# Validation Accuracy: 100.00%
# Fold 8/10
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0011 - accuracy: 1.0000
# Validation Accuracy: 100.00%
# Fold 9/10
# 1/1 [==============================] - 0s 71ms/step - loss: 1.5459e-04 - accuracy: 1.0000
# Validation Accuracy: 100.00%
# Fold 10/10
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0010 - accuracy: 1.0000
# Validation Accuracy: 100.00%

# %%
import warnings
warnings.filterwarnings("ignore")

plants_model = keras.models.load_model('/content/drive/MyDrive/SIH 2023/PlantsModel.h5')

# %%
import cv2
import numpy as np
import os
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.metrics import classification_report, accuracy_score

# plants_model = keras.models.load_model('/content/drive/MyDrive/SIH 2023/PlantsModel.h5')  # Replace with your loaded model

data_directory = '/content/drive/MyDrive/SIH 2023/Medicinal plant dataset'

rescale_factor = 1.0 / 255.0
rotation_range = 180
brightness_range = (0.2, 1.0)
horizontal_flip = True

transformed_images = []
true_labels = []

class_folders = sorted(os.listdir(data_directory))
for class_name in class_folders:
    class_directory = os.path.join(data_directory, class_name)

    for image_filename in os.listdir(class_directory):
        image_path = os.path.join(class_directory, image_filename)

        image = load_img(image_path, target_size=(299, 299))
        image = img_to_array(image)

        image *= rescale_factor

        if rotation_range:
            angle = np.random.uniform(-rotation_range, rotation_range)
            M = cv2.getRotationMatrix2D((image.shape[1] / 2, image.shape[0] / 2), angle, 1)
            image = cv2.warpAffine(image, M, (image.shape[1], image.shape[0]))

        if brightness_range:
            brightness_factor = np.random.uniform(brightness_range[0], brightness_range[1])
            image *= brightness_factor
            image = np.clip(image, 0, 255)

        if horizontal_flip and np.random.random() < 0.5:
            image = np.fliplr(image)


        transformed_images.append(image)
        true_labels.append(train_imgs.class_indices[class_name])


    transformed_images = np.array(transformed_images)
    true_labels = np.array(true_labels)


    predictions = plants_model.predict(transformed_images)
    print('\n \n Printing classification report for ', class_name,'\n\n')

    predicted_labels = np.argmax(predictions, axis=1)
    accuracy = accuracy_score(true_labels, predicted_labels)
    report = classification_report(true_labels, predicted_labels)
    print("Accuracy:", accuracy)
    print(report)
    transformed_images = []
    true_labels = []
# Out:
# 6/6 [==============================] - 2s 248ms/step
#
#
#  Printing classification report for  Aloevera
#
#
# Accuracy: 0.9942528735632183
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       174
#           32       0.00      0.00      0.00         0
#
#     accuracy                           0.99       174
#    macro avg       0.50      0.50      0.50       174
# weighted avg       1.00      0.99      1.00       174
#
# 5/5 [==============================] - 1s 255ms/step
#
#
#  Printing classification report for  Amla
#
#
# Accuracy: 0.952054794520548
#               precision    recall  f1-score   support
#
#            1       1.00      0.95      0.98       146
#            9       0.00      0.00      0.00         0
#           13       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           27       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#
#     accuracy                           0.95       146
#    macro avg       0.14      0.14      0.14       146
# weighted avg       1.00      0.95      0.98       146
#
# 5/5 [==============================] - 1s 249ms/step
#
#
#  Printing classification report for  Amruta_Balli
#
#
# Accuracy: 0.6575342465753424
#               precision    recall  f1-score   support
#
#            2       1.00      0.66      0.79       146
#            8       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           34       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.66       146
#    macro avg       0.06      0.04      0.05       146
# weighted avg       1.00      0.66      0.79       146
#
# 5/5 [==============================] - 1s 254ms/step
#
#
#  Printing classification report for  Arali
#
#
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00       146
#
#     accuracy                           1.00       146
#    macro avg       1.00      1.00      1.00       146
# weighted avg       1.00      1.00      1.00       146
#
# 5/5 [==============================] - 1s 252ms/step
#
#
#  Printing classification report for  Ashoka
#
#
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            4       1.00      1.00      1.00       146
#
#     accuracy                           1.00       146
#    macro avg       1.00      1.00      1.00       146
# weighted avg       1.00      1.00      1.00       146
#
# 5/5 [==============================] - 1s 254ms/step
#
#
#  Printing classification report for  Ashwagandha
#
#
# Accuracy: 0.8424657534246576
#               precision    recall  f1-score   support
#
#            5       1.00      0.84      0.91       146
#            8       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           31       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#
#     accuracy                           0.84       146
#    macro avg       0.11      0.09      0.10       146
# weighted avg       1.00      0.84      0.91       146
#
# 5/5 [==============================] - 1s 253ms/step
#
#
#  Printing classification report for  Avacado
#
#
# Accuracy: 0.9794520547945206
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         0
#            6       1.00      0.98      0.99       146
#           14       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#
#     accuracy                           0.98       146
#    macro avg       0.25      0.24      0.25       146
# weighted avg       1.00      0.98      0.99       146
#
# 5/5 [==============================] - 1s 254ms/step
#
#
#  Printing classification report for  Bamboo
#
#
# Accuracy: 0.9246575342465754
#               precision    recall  f1-score   support
#
#            6       0.00      0.00      0.00         0
#            7       1.00      0.92      0.96       146
#            9       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           26       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.92       146
#    macro avg       0.10      0.09      0.10       146
# weighted avg       1.00      0.92      0.96       146
#
# 5/5 [==============================] - 1s 254ms/step
#
#
#  Printing classification report for  Basale
#
#
# Accuracy: 0.9246575342465754
#               precision    recall  f1-score   support
#
#            8       1.00      0.92      0.96       146
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           16       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#
#     accuracy                           0.92       146
#    macro avg       0.12      0.12      0.12       146
# weighted avg       1.00      0.92      0.96       146
#
# 5/5 [==============================] - 1s 251ms/step
#
#
#  Printing classification report for  Betel
#
#
# Accuracy: 0.9205298013245033
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#            9       1.00      0.92      0.96       151
#           17       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           33       0.00      0.00      0.00         0
#
#     accuracy                           0.92       151
#    macro avg       0.12      0.12      0.12       151
# weighted avg       1.00      0.92      0.96       151
#
# 5/5 [==============================] - 1s 255ms/step
#
#
#  Printing classification report for  Betel_Nut
#
#
# Accuracy: 0.958904109589041
#               precision    recall  f1-score   support
#
#            6       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           10       1.00      0.96      0.98       146
#
#     accuracy                           0.96       146
#    macro avg       0.33      0.32      0.33       146
# weighted avg       1.00      0.96      0.98       146
#
# 5/5 [==============================] - 1s 246ms/step
#
#
#  Printing classification report for  Brahmi
#
#
# Accuracy: 0.958904109589041
#               precision    recall  f1-score   support
#
#           11       1.00      0.96      0.98       146
#           19       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           27       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#
#     accuracy                           0.96       146
#    macro avg       0.20      0.19      0.20       146
# weighted avg       1.00      0.96      0.98       146
#
# 5/5 [==============================] - 1s 250ms/step
#
#
#  Printing classification report for  Castor
#
#
# Accuracy: 0.95
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#           12       1.00      0.95      0.97       160
#           19       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#
#     accuracy                           0.95       160
#    macro avg       0.14      0.14      0.14       160
# weighted avg       1.00      0.95      0.97       160
#
# 5/5 [==============================] - 1s 242ms/step
#
#
#  Printing classification report for  Curry_Leaf
#
#
# Accuracy: 0.7602739726027398
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           13       1.00      0.76      0.86       146
#           19       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           34       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.76       146
#    macro avg       0.09      0.07      0.08       146
# weighted avg       1.00      0.76      0.86       146
#
# 5/5 [==============================] - 1s 240ms/step
#
#
#  Printing classification report for  Doddapatre
#
#
# Accuracy: 0.9931506849315068
#               precision    recall  f1-score   support
#
#           14       1.00      0.99      1.00       146
#           27       0.00      0.00      0.00         0
#
#     accuracy                           0.99       146
#    macro avg       0.50      0.50      0.50       146
# weighted avg       1.00      0.99      1.00       146
#
# 5/5 [==============================] - 1s 235ms/step
#
#
#  Printing classification report for  Ekka
#
#
# Accuracy: 0.9794520547945206
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           15       1.00      0.98      0.99       146
#           17       0.00      0.00      0.00         0
#
#     accuracy                           0.98       146
#    macro avg       0.25      0.24      0.25       146
# weighted avg       1.00      0.98      0.99       146
#
# 4/4 [==============================] - 1s 232ms/step
#
#
#  Printing classification report for  Ganike
#
#
# Accuracy: 0.6434782608695652
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#           16       1.00      0.64      0.78       115
#           21       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#
#     accuracy                           0.64       115
#    macro avg       0.20      0.13      0.16       115
# weighted avg       1.00      0.64      0.78       115
#
# 5/5 [==============================] - 1s 239ms/step
#
#
#  Printing classification report for  Gauva
#
#
# Accuracy: 0.958904109589041
#               precision    recall  f1-score   support
#
#           12       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           17       1.00      0.96      0.98       146
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#
#     accuracy                           0.96       146
#    macro avg       0.17      0.16      0.16       146
# weighted avg       1.00      0.96      0.98       146
#
# 5/5 [==============================] - 1s 242ms/step
#
#
#  Printing classification report for  Geranium
#
#
# Accuracy: 0.8493150684931506
#               precision    recall  f1-score   support
#
#            6       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           18       1.00      0.85      0.92       146
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           33       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#
#     accuracy                           0.85       146
#    macro avg       0.08      0.07      0.08       146
# weighted avg       1.00      0.85      0.92       146
#
# 5/5 [==============================] - 1s 240ms/step
#
#
#  Printing classification report for  Henna
#
#
# Accuracy: 0.7933333333333333
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#            8       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           19       1.00      0.79      0.88       150
#           21       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           31       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           37       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.79       150
#    macro avg       0.06      0.05      0.06       150
# weighted avg       1.00      0.79      0.88       150
#
# 6/6 [==============================] - 1s 237ms/step
#
#
#  Printing classification report for  Hibiscus
#
#
# Accuracy: 0.9272727272727272
#               precision    recall  f1-score   support
#
#            9       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           20       1.00      0.93      0.96       165
#           23       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#
#     accuracy                           0.93       165
#    macro avg       0.12      0.12      0.12       165
# weighted avg       1.00      0.93      0.96       165
#
# 5/5 [==============================] - 1s 243ms/step
#
#
#  Printing classification report for  Honge
#
#
# Accuracy: 0.9931506849315068
#               precision    recall  f1-score   support
#
#           19       0.00      0.00      0.00         0
#           21       1.00      0.99      1.00       146
#
#     accuracy                           0.99       146
#    macro avg       0.50      0.50      0.50       146
# weighted avg       1.00      0.99      1.00       146
#
# 5/5 [==============================] - 1s 233ms/step
#
#
#  Printing classification report for  Insulin
#
#
# Accuracy: 0.8904109589041096
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           22       1.00      0.89      0.94       146
#           30       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           37       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.89       146
#    macro avg       0.11      0.10      0.10       146
# weighted avg       1.00      0.89      0.94       146
#
# 6/6 [==============================] - 1s 247ms/step
#
#
#  Printing classification report for  Jasmine
#
#
# Accuracy: 0.8074866310160428
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           18       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           23       1.00      0.81      0.89       187
#           34       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#
#     accuracy                           0.81       187
#    macro avg       0.08      0.06      0.07       187
# weighted avg       1.00      0.81      0.89       187
#
# 5/5 [==============================] - 1s 234ms/step
#
#
#  Printing classification report for  Lemon
#
#
# Accuracy: 0.8571428571428571
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           24       1.00      0.86      0.92       154
#           32       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.86       154
#    macro avg       0.12      0.11      0.12       154
# weighted avg       1.00      0.86      0.92       154
#
# 5/5 [==============================] - 1s 240ms/step
#
#
#  Printing classification report for  Lemon_grass
#
#
# Accuracy: 0.9594594594594594
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           25       1.00      0.96      0.98       148
#           29       0.00      0.00      0.00         0
#           34       0.00      0.00      0.00         0
#
#     accuracy                           0.96       148
#    macro avg       0.20      0.19      0.20       148
# weighted avg       1.00      0.96      0.98       148
#
# 5/5 [==============================] - 1s 237ms/step
#
#
#  Printing classification report for  Mango
#
#
# Accuracy: 0.589041095890411
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           26       1.00      0.59      0.74       146
#           29       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.59       146
#    macro avg       0.06      0.03      0.04       146
# weighted avg       1.00      0.59      0.74       146
#
# 6/6 [==============================] - 1s 238ms/step
#
#
#  Printing classification report for  Mint
#
#
# Accuracy: 0.9570552147239264
#               precision    recall  f1-score   support
#
#           21       0.00      0.00      0.00         0
#           27       1.00      0.96      0.98       163
#           28       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.96       163
#    macro avg       0.25      0.24      0.24       163
# weighted avg       1.00      0.96      0.98       163
#
# 6/6 [==============================] - 1s 240ms/step
#
#
#  Printing classification report for  Nagadali
#
#
# Accuracy: 0.8024691358024691
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           16       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           27       0.00      0.00      0.00         0
#           28       1.00      0.80      0.89       162
#           29       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#
#     accuracy                           0.80       162
#    macro avg       0.10      0.08      0.09       162
# weighted avg       1.00      0.80      0.89       162
#
# 6/6 [==============================] - 1s 241ms/step
#
#
#  Printing classification report for  Neem
#
#
# Accuracy: 0.9337349397590361
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           26       0.00      0.00      0.00         0
#           27       0.00      0.00      0.00         0
#           29       1.00      0.93      0.97       166
#           30       0.00      0.00      0.00         0
#           34       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#
#     accuracy                           0.93       166
#    macro avg       0.10      0.09      0.10       166
# weighted avg       1.00      0.93      0.97       166
#
# 5/5 [==============================] - 1s 250ms/step
#
#
#  Printing classification report for  Nithyapushpa
#
#
# Accuracy: 0.952054794520548
#               precision    recall  f1-score   support
#
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           30       1.00      0.95      0.98       146
#           32       0.00      0.00      0.00         0
#
#     accuracy                           0.95       146
#    macro avg       0.14      0.14      0.14       146
# weighted avg       1.00      0.95      0.98       146
#
# 5/5 [==============================] - 1s 242ms/step
#
#
#  Printing classification report for  Nooni
#
#
# Accuracy: 0.9452054794520548
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           26       0.00      0.00      0.00         0
#           31       1.00      0.95      0.97       146
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.95       146
#    macro avg       0.11      0.11      0.11       146
# weighted avg       1.00      0.95      0.97       146
#
# 5/5 [==============================] - 1s 248ms/step
#
#
#  Printing classification report for  Pappaya
#
#
# Accuracy: 0.8835616438356164
#               precision    recall  f1-score   support
#
#           14       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           32       1.00      0.88      0.94       146
#           36       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.88       146
#    macro avg       0.12      0.11      0.12       146
# weighted avg       1.00      0.88      0.94       146
#
# 5/5 [==============================] - 1s 250ms/step
#
#
#  Printing classification report for  Pepper
#
#
# Accuracy: 0.9383561643835616
#               precision    recall  f1-score   support
#
#            5       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           33       1.00      0.94      0.97       146
#           35       0.00      0.00      0.00         0
#
#     accuracy                           0.94       146
#    macro avg       0.20      0.19      0.19       146
# weighted avg       1.00      0.94      0.97       146
#
# 5/5 [==============================] - 1s 246ms/step
#
#
#  Printing classification report for  Pomegranate
#
#
# Accuracy: 0.8013698630136986
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           26       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           34       1.00      0.80      0.89       146
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.80       146
#    macro avg       0.09      0.07      0.08       146
# weighted avg       1.00      0.80      0.89       146
#
# 5/5 [==============================] - 1s 247ms/step
#
#
#  Printing classification report for  Raktachandini
#
#
# Accuracy: 0.8767123287671232
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           33       0.00      0.00      0.00         0
#           35       1.00      0.88      0.93       146
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.88       146
#    macro avg       0.09      0.08      0.08       146
# weighted avg       1.00      0.88      0.93       146
#
# 6/6 [==============================] - 1s 247ms/step
#
#
#  Printing classification report for  Rose
#
#
# Accuracy: 0.9047619047619048
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           36       1.00      0.90      0.95       168
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.90       168
#    macro avg       0.09      0.08      0.09       168
# weighted avg       1.00      0.90      0.95       168
#
# 5/5 [==============================] - 1s 255ms/step
#
#
#  Printing classification report for  Sapota
#
#
# Accuracy: 0.8698630136986302
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           31       0.00      0.00      0.00         0
#           37       1.00      0.87      0.93       146
#           38       0.00      0.00      0.00         0
#
#     accuracy                           0.87       146
#    macro avg       0.10      0.09      0.09       146
# weighted avg       1.00      0.87      0.93       146
#
# 5/5 [==============================] - 1s 243ms/step
#
#
#  Printing classification report for  Tulasi
#
#
# Accuracy: 0.9315068493150684
#               precision    recall  f1-score   support
#
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           31       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#           38       1.00      0.93      0.96       146
#
#     accuracy                           0.93       146
#    macro avg       0.14      0.13      0.14       146
# weighted avg       1.00      0.93      0.96       146
#
# 5/5 [==============================] - 1s 245ms/step
#
#
#  Printing classification report for  Wood_sorel
#
#
# Accuracy: 0.9726027397260274
#               precision    recall  f1-score   support
#
#           17       0.00      0.00      0.00         0
#           27       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#           39       1.00      0.97      0.99       146
#
#     accuracy                           0.97       146
#    macro avg       0.25      0.24      0.25       146
# weighted avg       1.00      0.97      0.99       146

# %%
# Out:
# 0
